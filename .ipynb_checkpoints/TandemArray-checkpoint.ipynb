# %%
import pm4py
from operator import itemgetter

# %%
def listSearch(T,keyword, start=0):
    try :
        idx = T.index(keyword,start)
    except : 
        return []
    return [idx] + listSearch(T,keyword,idx+1)

# %%
def tandemArray(T) : 
    total=[]
    readT=[]
    print(T)
    for currentPosition in range(len(T)): #current position moves from the left to the right by 1
        print("="*100)
        print("readT", readT,"current", T[currentPosition])
        indices=listSearch(readT,T[currentPosition])
        print("indices", indices)
        
        for s in indices :
            pattern=readT[s:currentPosition]
            length = currentPosition-s
#             print("pattern to be searched", pattern, s, s+length-1)
            position = currentPosition
            c=0
            while True :
                if pattern  == T[position:position+length] : 
#                     print("\tFOUND : ", position, position + length-1, T[position:position+length])
                    c+=1
                    position +=length
                else :
                    if c>0 : total.append(
                        [s,','.join(pattern),c+1, s+len(pattern)*(c+1)-1 ]
                    )
                    break
        readT.append(T[currentPosition])
    print("="*100,"\n", "original tandem array\n","="*100)
    print(total) 
    total=maximalTandemArray(total)
    print("="*100,"\n", "maximal tandem array only\n", "="*100)
    print(total)
    total=extractPrimitiveTandemArray(total)
    print("="*100,"\n", "primitive tandem array\n", "="*100)
    print(total)    
    return total

# %%
def maximalTandemArray(T) :
    deleteidx = []
    comparision = [0,'',0,0]
    T.sort(key=itemgetter(1,0))
    for idx, item in enumerate(T) : 
        #print(idx, comparision, item)
        if ((comparision[1] == item[1]) & (comparision[3]==item[3])) : #if trace is equal
            #print("equal")
            if (comparision[0] <= item[0]) & (comparision[3]==item[3]) :
                #print(comparision[0] <= item[0],  comparision[3]==item[3], "delete", idx)
                deleteidx.append(idx)
        else : #if trace is not equal
            comparision = item #current item to be inserted into comparision
            #print("false, change comparision", item)
    #end for   
    deleteidx=list(set(deleteidx))
    deleteidx.sort()
    deleteidx.reverse()
    #print(deleteidx)
    for k in deleteidx : 
        #print(k, "delete", T[k])
        del T[k]
    
    return T

# %%
def extractPrimitiveTandemArray (tandemarray) : 
    repeatedType=[]
    toDelete=[]
    for i in tandemarray : 
        repeatedType.append(i[1])

    for i in range(len(repeatedType)) :
        reg='(' + str(repeatedType[i])+',?' + ')' + '{2,}'
        p=re.compile(reg)
#         print("regular expresss", reg)
        for j in range(i+1, len(repeatedType)) :
#             print("i", repeatedType[i], "j", repeatedType[j])
#             print(p.match(repeatedType[j]))
            if (
                ((p.match(repeatedType[j]))!=None ) & 
                (repeatedType[i]!=repeatedType[j])
            ): #if the pattern exists by comparision using RegularExpression
#                 print(repeatedType[i],'\t' , repeatedType[j], '\t',j)
                toDelete.append(j)
    toDelete=list(set(toDelete))
    toDelete.sort()
    toDelete.reverse()
    #print(toDelete)
    for k in toDelete : 
#         print(k, "delete", tandemarray[k])
        del tandemarray[k]
    
    return tandemarray

# %%
T1=['g','d','a','b','c','a','b','c','a','b','c','a','b','c','a','f','i','c','a','a','b','c','a','b','c','a','b','c','a','b','c']
T2=['a','b','a','b','a','b','a','b','c','d','a','b','c','d','a','b','a','b','c','d','a','b']

# %%
a=tandemArray(T1)
# Out:
# ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c']
# ====================================================================================================
# readT [] current g
# indices []
# ====================================================================================================
# readT ['g'] current d
# indices []
# ====================================================================================================
# readT ['g', 'd'] current a
# indices []
# ====================================================================================================
# readT ['g', 'd', 'a'] current b
# indices []
# ====================================================================================================
# readT ['g', 'd', 'a', 'b'] current c
# indices []
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c'] current a
# indices [2]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a'] current b
# indices [3]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b'] current c
# indices [4]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c'] current a
# indices [2, 5]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a'] current b
# indices [3, 6]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b'] current c
# indices [4, 7]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c'] current a
# indices [2, 5, 8]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a'] current b
# indices [3, 6, 9]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b'] current c
# indices [4, 7, 10]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c'] current a
# indices [2, 5, 8, 11]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a'] current f
# indices []
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f'] current i
# indices []
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i'] current c
# indices [4, 7, 10, 13]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c'] current a
# indices [2, 5, 8, 11, 14]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a'] current a
# indices [2, 5, 8, 11, 14, 18]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a'] current b
# indices [3, 6, 9, 12]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a', 'b'] current c
# indices [4, 7, 10, 13, 17]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a', 'b', 'c'] current a
# indices [2, 5, 8, 11, 14, 18, 19]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a', 'b', 'c', 'a'] current b
# indices [3, 6, 9, 12, 20]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a', 'b', 'c', 'a', 'b'] current c
# indices [4, 7, 10, 13, 17, 21]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a', 'b', 'c', 'a', 'b', 'c'] current a
# indices [2, 5, 8, 11, 14, 18, 19, 22]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a', 'b', 'c', 'a', 'b', 'c', 'a'] current b
# indices [3, 6, 9, 12, 20, 23]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b'] current c
# indices [4, 7, 10, 13, 17, 21, 24]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c'] current a
# indices [2, 5, 8, 11, 14, 18, 19, 22, 25]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a'] current b
# indices [3, 6, 9, 12, 20, 23, 26]
# ====================================================================================================
# readT ['g', 'd', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'f', 'i', 'c', 'a', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b'] current c
# indices [4, 7, 10, 13, 17, 21, 24, 27]
# ====================================================================================================
#  original tandem array
#  ====================================================================================================
# [[2, 'a,b,c', 4, 13], [3, 'b,c,a', 4, 14], [4, 'c,a,b', 3, 12], [2, 'a,b,c,a,b,c', 2, 13], [5, 'a,b,c', 3, 13], [3, 'b,c,a,b,c,a', 2, 14], [6, 'b,c,a', 3, 14], [7, 'c,a,b', 2, 12], [8, 'a,b,c', 2, 13], [9, 'b,c,a', 2, 14], [18, 'a', 2, 19], [19, 'a,b,c', 4, 30], [20, 'b,c,a', 3, 28], [21, 'c,a,b', 3, 29], [19, 'a,b,c,a,b,c', 2, 30], [22, 'a,b,c', 3, 30], [23, 'b,c,a', 2, 28], [24, 'c,a,b', 2, 29], [25, 'a,b,c', 2, 30]]
# ====================================================================================================
#  maximal tandem array only
#  ====================================================================================================
# [[18, 'a', 2, 19], [2, 'a,b,c', 4, 13], [19, 'a,b,c', 4, 30], [2, 'a,b,c,a,b,c', 2, 13], [19, 'a,b,c,a,b,c', 2, 30], [3, 'b,c,a', 4, 14], [20, 'b,c,a', 3, 28], [3, 'b,c,a,b,c,a', 2, 14], [4, 'c,a,b', 3, 12], [21, 'c,a,b', 3, 29]]
# ====================================================================================================
#  primitive tandem array
#  ====================================================================================================
# [[18, 'a', 2, 19], [2, 'a,b,c', 4, 13], [19, 'a,b,c', 4, 30], [3, 'b,c,a', 4, 14], [20, 'b,c,a', 3, 28], [4, 'c,a,b', 3, 12], [21, 'c,a,b', 3, 29]]

# %%
a.sort(key=itemgetter(1, 0))

# %%
a
# Out:
# [[18, 'a', 2, 19],
#  [2, 'a,b,c', 4, 13],
#  [5, 'a,b,c', 3, 13],
#  [8, 'a,b,c', 2, 13],
#  [19, 'a,b,c', 4, 30],
#  [22, 'a,b,c', 3, 30],
#  [25, 'a,b,c', 2, 30],
#  [2, 'a,b,c,a,b,c', 2, 13],
#  [19, 'a,b,c,a,b,c', 2, 30],
#  [3, 'b,c,a', 4, 14],
#  [6, 'b,c,a', 3, 14],
#  [9, 'b,c,a', 2, 14],
#  [20, 'b,c,a', 3, 28],
#  [23, 'b,c,a', 2, 28],
#  [3, 'b,c,a,b,c,a', 2, 14],
#  [4, 'c,a,b', 3, 12],
#  [7, 'c,a,b', 2, 12],
#  [21, 'c,a,b', 3, 29],
#  [24, 'c,a,b', 2, 29]]

# %%
# Your code
from pm4py.objects.log.importer.xes import factory as xes_importer
from pm4py.algo.filtering.log.variants import variants_filter
from pm4py.statistics.traces.log import case_statistics
from pm4py.visualization.petrinet import factory as vis_factory

log = xes_importer.import_log("event_log.xes")
variants_count = case_statistics.get_variant_statistics(log)
variants_count = sorted(variants_count, key=lambda x: x['count'], reverse=True)

l = []
for i in variants_count:
    if i['count'] == 1:
        l.append(i)

print("least frequent variant")
for j in l:
    print(j['variant'])

print(" ")
print("most frequent variant")
print(variants_count[0]['variant'])
# Out:
# least frequent variant
# Wait,Resolve ticket,Closed
# Take in charge ticket,Wait,Wait,Resolve ticket,Closed
# Take in charge ticket,Wait,Resolve ticket,Take in charge ticket,Wait,Resolve ticket,Closed
# Take in charge ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed
# Take in charge ticket,Take in charge ticket,Resolve ticket,Closed
# Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Wait,Resolve ticket,Closed
# Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Take in charge ticket,Resolve ticket,Resolve ticket,Resolve ticket,Closed
# Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Resolve ticket,Closed
# Insert ticket,Wait,Wait,Wait,Wait
# Insert ticket,Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Resolve ticket,Closed
# Insert ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Resolve ticket,Closed
# Insert ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Insert ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Closed
# Insert ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Closed,Closed
# Insert ticket,Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed
# Insert ticket,Assign seriousness,Take in charge ticket,Assign seriousness,Assign seriousness,Wait,Take in charge ticket,Resolve ticket,Closed
# Insert ticket,Assign seriousness,Resolve ticket,Closed
# Insert ticket,Assign seriousness,Assign seriousness,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Insert ticket,Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Closed
# Insert ticket,Assign seriousness,Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed
# Create SW anomaly,Resolve SW anomaly,Resolve ticket,Closed
# Assign seriousness,Wait,Wait,Take in charge ticket,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Wait,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Wait,Wait,Resolve ticket,Take in charge ticket,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Wait,Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Wait,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Wait,Wait,Wait,Wait
# Assign seriousness,Take in charge ticket,Wait,Wait,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Wait,Wait,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Wait,Wait,Take in charge ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Wait,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Wait,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Resolve ticket,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Wait,Resolve ticket,Take in charge ticket,Wait,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Wait,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Wait,Create SW anomaly,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Require upgrade,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Require upgrade,Resolve ticket
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Create SW anomaly,Resolve ticket,RESOLVED,INVALID,Closed,VERIFIED
# Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Wait,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Require upgrade,Wait,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Require upgrade,Wait,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Require upgrade,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Require upgrade,Require upgrade,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait,Require upgrade
# Assign seriousness,Take in charge ticket,Wait,Create SW anomaly,Require upgrade,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Wait
# Assign seriousness,Take in charge ticket,Take in charge ticket,Wait,Wait,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Take in charge ticket,Take in charge ticket,Wait,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Take in charge ticket,Schedule intervention,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Take in charge ticket,Require upgrade,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Schedule intervention,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Wait,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Wait,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Take in charge ticket,Wait,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Closed,Closed
# Assign seriousness,Take in charge ticket,Resolve ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Resolve SW anomaly,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Require upgrade,Take in charge ticket,Wait,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Require upgrade,Require upgrade,Take in charge ticket,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Require upgrade,Require upgrade,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Require upgrade,Require upgrade,Require upgrade,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Require upgrade,Require upgrade,Create SW anomaly,Require upgrade
# Assign seriousness,Take in charge ticket,Require upgrade,Create SW anomaly,Resolve ticket,RESOLVED,INVALID,VERIFIED,Closed
# Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve SW anomaly,Resolve SW anomaly,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve SW anomaly,Resolve SW anomaly,Require upgrade
# Assign seriousness,Take in charge ticket,Create SW anomaly,Create SW anomaly,Resolve ticket,Closed
# Assign seriousness,Take in charge ticket,Create SW anomaly,Create SW anomaly,Resolve SW anomaly,Resolve SW anomaly,Require upgrade,Create SW anomaly,Resolve ticket
# Assign seriousness,Resolve ticket,Wait,Wait,Resolve ticket,Closed
# Assign seriousness,Resolve ticket,Take in charge ticket,Require upgrade,Resolve ticket,Closed
# Assign seriousness,Resolve ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Resolve ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Resolve ticket,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Resolve ticket,Closed,Take in charge ticket
# Assign seriousness,Require upgrade,Require upgrade,Resolve ticket,Closed
# Assign seriousness,Create SW anomaly,Take in charge ticket,Create SW anomaly,Require upgrade,VERIFIED,DUPLICATE,Resolve ticket,Closed
# Assign seriousness,Create SW anomaly,Require upgrade,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Wait,Wait,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Wait
# Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Require upgrade,Require upgrade,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Schedule intervention,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Resolve ticket,Resolve ticket,Require upgrade,Take in charge ticket,Wait,Wait,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Require upgrade,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Require upgrade,Require upgrade,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve SW anomaly,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Assign seriousness,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Assign seriousness,Wait,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Assign seriousness,Resolve ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed
# Assign seriousness,Assign seriousness,Assign seriousness,Assign seriousness,Resolve ticket,Take in charge ticket,Resolve ticket,Closed
#
# most frequent variant
# Assign seriousness,Take in charge ticket,Resolve ticket,Closed

# %%
print(log[1])
# Out:
# {'attributes': {'concept:name': 'Case 10'}, 'events': [{'Resource': 'Value 2', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 3', 'support_section': 'Value 2', 'customer': 'Value 10', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 2', 'time:timestamp': datetime.datetime(2010, 2, 10, 8, 50, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 3', 'support_section': 'Value 2', 'customer': 'Value 10', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 2', 'time:timestamp': datetime.datetime(2010, 4, 3, 7, 47, 38, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}

# %%
for i in log:
    print(i)
    for j in  i : print(j['concept:name'])
# Out:
# {'attributes': {'concept:name': 'Case 1'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 1', 'service_level': 'Value 1', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 12, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 10, 9, 14, 50, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 12', 'Variant': 'Variant 12'}, '..', {'Resource': 'Value 3', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 1', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 12, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 11, 9, 12, 54, 39, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 12', 'Variant': 'Variant 12'}]}
# Assign seriousness
# Take in charge ticket
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 10'}, 'events': [{'Resource': 'Value 2', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 3', 'support_section': 'Value 2', 'customer': 'Value 10', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 2', 'time:timestamp': datetime.datetime(2010, 2, 10, 8, 50, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 3', 'support_section': 'Value 2', 'customer': 'Value 10', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 2', 'time:timestamp': datetime.datetime(2010, 4, 3, 7, 47, 38, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 100'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 44', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 10, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 4, 12, 10, 25, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 10', 'Variant': 'Variant 10'}, '..', {'Resource': 'Value 3', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 44', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 10, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 5, 30, 13, 21, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 10', 'Variant': 'Variant 10'}]}
# Assign seriousness
# Take in charge ticket
# Require upgrade
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1000'}, 'events': [{'Resource': 'Value 2', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 3', 'customer': 'Value 92', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 4, 'responsible_section': 'Value 4', 'time:timestamp': datetime.datetime(2010, 1, 21, 8, 53, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 4', 'Variant': 'Variant 4'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 3', 'customer': 'Value 92', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 4, 'responsible_section': 'Value 4', 'time:timestamp': datetime.datetime(2010, 3, 6, 9, 0, 57, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 4', 'Variant': 'Variant 4'}]}
# Assign seriousness
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1001'}, 'events': [{'Resource': 'Value 4', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 239', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 2', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 3, 8, 17, 1, 24, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 3', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 239', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 2', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 4, 12, 9, 31, 36, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1002'}, 'events': [{'Resource': 'Value 19', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 18', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 8, 25, 10, 36, 10, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 18', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 9, 25, 10, 40, 32, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1003'}, 'events': [{'Resource': 'Value 8', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 20', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 12, 23, 11, 23, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 20', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 2, 4, 10, 59, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1004'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 27', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 9, 21, 7, 9, 20, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 27', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 10, 22, 7, 10, 49, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1005'}, 'events': [{'Resource': 'Value 8', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 83', 'service_level': 'Value 1', 'concept:name': 'Assign seriousness', 'product': 'Value 2', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 12, 22, 8, 35, 14, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 83', 'service_level': 'Value 1', 'concept:name': 'Closed', 'product': 'Value 2', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 2, 18, 8, 40, 43, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1006'}, 'events': [{'Resource': 'Value 2', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 5', 'customer': 'Value 255', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 6', 'time:timestamp': datetime.datetime(2010, 1, 22, 11, 9, 40, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 5', 'customer': 'Value 255', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 6', 'time:timestamp': datetime.datetime(2010, 3, 11, 11, 10, 33, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1007'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 256', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 10, 10, 10, 47, 41, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 3', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 256', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 11, 27, 8, 37, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1008'}, 'events': [{'Resource': 'Value 4', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 96', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 10, 25, 14, 35, 19, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 96', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 12, 8, 15, 40, 25, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1009'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 26', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 5, 18, 12, 11, 25, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 26', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 6, 28, 14, 10, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}]}
# Assign seriousness
# Take in charge ticket
# Wait
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 101'}, 'events': [{'Resource': 'Value 15', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 18', 'service_level': 'Value 2', 'concept:name': 'Insert ticket', 'product': 'Value 3', 'Variant2 index': 7, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 6, 18, 13, 47, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 7', 'Variant': 'Variant 7'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 18', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 7, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 8, 5, 13, 50, 24, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 7', 'Variant': 'Variant 7'}]}
# Insert ticket
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1010'}, 'events': [{'Resource': 'Value 14', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 177', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 10, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 6, 21, 7, 11, 34, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 10', 'Variant': 'Variant 10'}, '..', {'Resource': 'Value 3', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 177', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 10, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 8, 1, 15, 39, 11, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 10', 'Variant': 'Variant 10'}]}
# Assign seriousness
# Take in charge ticket
# Require upgrade
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1011'}, 'events': [{'Resource': 'Value 15', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 163', 'service_level': 'Value 2', 'concept:name': 'Insert ticket', 'product': 'Value 3', 'Variant2 index': 7, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 9, 6, 15, 37, 27, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 7', 'Variant': 'Variant 7'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 163', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 7, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 10, 22, 15, 40, 25, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 7', 'Variant': 'Variant 7'}]}
# Insert ticket
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1012'}, 'events': [{'Resource': 'Value 2', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 182', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 5, 25, 15, 14, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 182', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 6, 26, 15, 20, 26, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1013'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 18', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 5, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 11, 30, 16, 32, 54, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 5', 'Variant': 'Variant 5'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 18', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 5, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 1, 13, 16, 40, 37, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 5', 'Variant': 'Variant 5'}]}
# Assign seriousness
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1014'}, 'events': [{'Resource': 'Value 8', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 9', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 3, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 12, 28, 10, 41, 6, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 3', 'Variant': 'Variant 3'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 9', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 3, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 1, 28, 16, 55, 37, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 3', 'Variant': 'Variant 3'}]}
# Assign seriousness
# Take in charge ticket
# Wait
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1015'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 14', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 2', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 2, 10, 14, 44, 10, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 14', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 2', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 3, 14, 14, 50, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1016'}, 'events': [{'Resource': 'Value 8', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 8', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 4, 13, 7, 43, 1, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 8', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 6, 11, 7, 50, 56, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1017'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 104', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 26, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 9, 7, 12, 24, 46, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 26', 'Variant': 'Variant 26'}, '..', {'Resource': 'Value 3', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 104', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 26, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 10, 17, 7, 3, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 26', 'Variant': 'Variant 26'}]}
# Assign seriousness
# Take in charge ticket
# Wait
# Resolve ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1018'}, 'events': [{'Resource': 'Value 14', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 3', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 10', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 9, 16, 9, 3, 22, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 3', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 10', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 11, 5, 9, 24, 51, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1019'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 257', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 6', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 2, 14, 15, 35, 55, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}, '..', {'Resource': 'Value 3', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 257', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 6', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 3, 19, 10, 43, 39, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}]}
# Assign seriousness
# Take in charge ticket
# Wait
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 102'}, 'events': [{'Resource': 'Value 4', 'seriousness': 'Value 1', 'seriousness_2': 'Value 4', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 62', 'service_level': 'Value 1', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 1, 30, 9, 9, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 4', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 62', 'service_level': 'Value 1', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 3, 16, 9, 12, 11, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1020'}, 'events': [{'Resource': 'Value 4', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 220', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 2', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 5, 15, 8, 9, 38, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 220', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 2', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 7, 6, 13, 30, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}]}
# Assign seriousness
# Take in charge ticket
# Wait
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1021'}, 'events': [{'Resource': 'Value 6', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 5', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 5, 18, 14, 59, 36, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 5', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 6, 25, 15, 1, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1022'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 167', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 2', 'Variant2 index': 4, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 1, 5, 16, 55, 40, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 4', 'Variant': 'Variant 4'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 167', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 2', 'Variant2 index': 4, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 2, 7, 17, 0, 35, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 4', 'Variant': 'Variant 4'}]}
# Assign seriousness
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1023'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 237', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 8, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 3, 12, 9, 39, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 8', 'Variant': 'Variant 8'}, '..', {'Resource': 'Value 3', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 237', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 8, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 4, 12, 12, 15, 6, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 8', 'Variant': 'Variant 8'}]}
# Assign seriousness
# Resolve ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1024'}, 'events': [{'Resource': 'Value 13', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 75', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 4, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 7, 14, 7, 22, 19, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 4', 'Variant': 'Variant 4'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 75', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 4, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 8, 20, 7, 31, 38, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 4', 'Variant': 'Variant 4'}]}
# Assign seriousness
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1025'}, 'events': [{'Resource': 'Value 8', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 241', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 3, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 3, 18, 9, 41, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 3', 'Variant': 'Variant 3'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 241', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 3, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 5, 5, 15, 42, 36, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 3', 'Variant': 'Variant 3'}]}
# Assign seriousness
# Take in charge ticket
# Wait
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1026'}, 'events': [{'Resource': 'Value 14', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 104', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 10, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 5, 13, 15, 56, 12, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 10', 'Variant': 'Variant 10'}, '..', {'Resource': 'Value 3', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 104', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 10, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 6, 19, 16, 5, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 10', 'Variant': 'Variant 10'}]}
# Assign seriousness
# Take in charge ticket
# Require upgrade
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1027'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 74', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 4, 16, 13, 36, 13, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}, '..', {'Resource': 'Value 3', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 74', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2013, 5, 30, 9, 33, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}]}
# Assign seriousness
# Take in charge ticket
# Wait
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1028'}, 'events': [{'Resource': 'Value 8', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 71', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 12, 28, 8, 31, 42, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 71', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 1, 29, 10, 46, 26, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1029'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 49', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 5, 9, 9, 25, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 49', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 6, 9, 9, 30, 28, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 103'}, 'events': [{'Resource': 'Value 2', 'seriousness': 'Value 1', 'seriousness_2': 'Value 4', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 63', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 96, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 6, 7, 7, 30, 54, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 96', 'Variant': 'Variant 96'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 4', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 63', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 96, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 7, 16, 9, 23, 33, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 96', 'Variant': 'Variant 96'}]}
# Assign seriousness
# Assign seriousness
# Take in charge ticket
# Wait
# Take in charge ticket
# Create SW anomaly
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1030'}, 'events': [{'Resource': 'Value 2', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 6', 'customer': 'Value 110', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 115, 'responsible_section': 'Value 3', 'time:timestamp': datetime.datetime(2010, 2, 4, 9, 40, 52, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 115', 'Variant': 'Variant 115'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 6', 'customer': 'Value 110', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 115, 'responsible_section': 'Value 3', 'time:timestamp': datetime.datetime(2010, 3, 9, 14, 5, 44, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 115', 'Variant': 'Variant 115'}]}
# Assign seriousness
# Assign seriousness
# Take in charge ticket
# Create SW anomaly
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1031'}, 'events': [{'Resource': 'Value 8', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 220', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 2', 'Variant2 index': 3, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 2, 24, 13, 41, 36, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 3', 'Variant': 'Variant 3'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 220', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 2', 'Variant2 index': 3, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 4, 15, 14, 50, 58, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 3', 'Variant': 'Variant 3'}]}
# Assign seriousness
# Take in charge ticket
# Wait
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1032'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 71', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 4, 11, 15, 7, 25, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 71', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 6, 1, 15, 20, 26, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}]}
# Assign seriousness
# Take in charge ticket
# Wait
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 1033'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 22', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 11, 10, 8, 25, 5, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 22', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 12, 29, 11, 10, 47, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}]}
# Assign seriousness
# Take in charge ticket
# Wait
# Resolve ticket
# Closed
# ...
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 32'}, 'events': [{'Resource': 'Value 8', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 28', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 4, 27, 7, 38, 44, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 28', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 6, 4, 7, 40, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 320'}, 'events': [{'Resource': 'Value 13', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 143', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 4', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 12, 27, 16, 12, 53, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 143', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 4', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 2, 4, 10, 49, 1, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 3200'}, 'events': [{'Resource': 'Value 8', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 177', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 4, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 12, 28, 15, 53, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 4', 'Variant': 'Variant 4'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 177', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 4, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 2, 4, 16, 0, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 4', 'Variant': 'Variant 4'}]}
# Assign seriousness
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 3201'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 18', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 2', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 11, 17, 16, 12, 4, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 18', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 2', 'Variant2 index': 2, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 12, 27, 14, 50, 49, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 2', 'Variant': 'Variant 2'}]}
# Assign seriousness
# Take in charge ticket
# Wait
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 3202'}, 'events': [{'Resource': 'Value 13', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 118', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 4', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 9, 14, 9, 0, 15, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 118', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 4', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 10, 15, 9, 10, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 3203'}, 'events': [{'Resource': 'Value 2', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 5', 'customer': 'Value 138', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 6', 'time:timestamp': datetime.datetime(2010, 3, 17, 13, 26, 12, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 5', 'customer': 'Value 138', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 6', 'time:timestamp': datetime.datetime(2010, 4, 25, 9, 21, 42, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 3204'}, 'events': [{'Resource': 'Value 4', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 51', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 2, 2, 15, 35, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 51', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 3, 6, 15, 40, 26, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 3205'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 374', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 15', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 2, 7, 13, 31, 23, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 374', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 15', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 3, 9, 13, 40, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 3206'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 18', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 4', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 1, 9, 9, 59, 35, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 18', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 4', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 2, 9, 10, 0, 25, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 3207'}, 'events': [{'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 73', 'service_level': 'Value 3', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 8, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 10, 10, 7, 19, 3, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 8', 'Variant': 'Variant 8'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 73', 'service_level': 'Value 3', 'concept:name': 'Closed', 'product': 'Value 1', 'Variant2 index': 8, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 11, 16, 8, 28, 30, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 8', 'Variant': 'Variant 8'}]}
# Assign seriousness
# Resolve ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 3208'}, 'events': [{'Resource': 'Value 2', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 11', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 11, 9, 8, 29, 37, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 11', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2011, 12, 25, 8, 31, 49, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 3209'}, 'events': [{'Resource': 'Value 7', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 79', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 10, 26, 15, 18, 9, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 79', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 3', 'Variant2 index': 1, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 11, 27, 16, 20, 22, tzinfo=datetime.timezone(datetime.timedelta(seconds=3600))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 1', 'Variant': 'Variant 1'}]}
# Assign seriousness
# Take in charge ticket
# Resolve ticket
# Closed
# {'attributes': {'concept:name': 'Case 321'}, 'events': [{'Resource': 'Value 19', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 8', 'service_level': 'Value 2', 'concept:name': 'Assign seriousness', 'product': 'Value 9', 'Variant2 index': 13, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 7, 1, 9, 53, 2, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 13', 'Variant': 'Variant 13'}, '..', {'Resource': 'Value 5', 'seriousness': 'Value 1', 'seriousness_2': 'Value 2', 'service_type': 'Value 2', 'workgroup': 'Value 2', 'support_section': 'Value 1', 'customer': 'Value 8', 'service_level': 'Value 2', 'concept:name': 'Closed', 'product': 'Value 9', 'Variant2 index': 13, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2010, 8, 14, 10, 0, 29, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 13', 'Variant': 'Variant 13'}]}
# Assign seriousness
# Assign seriousness
# Take in charge ticket
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
log[0][0]
# Out:
# {'Resource': 'Value 1', 'seriousness': 'Value 1', 'seriousness_2': 'Value 1', 'service_type': 'Value 1', 'workgroup': 'Value 1', 'support_section': 'Value 1', 'customer': 'Value 1', 'service_level': 'Value 1', 'concept:name': 'Assign seriousness', 'product': 'Value 1', 'Variant2 index': 12, 'responsible_section': 'Value 1', 'time:timestamp': datetime.datetime(2012, 10, 9, 14, 50, 17, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))), 'lifecycle:transition': 'complete', 'Variant3': 'Variant 12', 'Variant': 'Variant 12'}

# %%
T2
# Out:
# ['a', 'b', 'a', 'b', 'a', 'b', 'a', 'b', 'c', 'd', 'a', 'b', 'c', 'd']

# %%
T2.index('a')
# Out:
# 0

# %%
T2.index('a',T2.index('a')+1)
# Out:
# 2

# %%
T2
# Out:
# ['a', 'b', 'a', 'b', 'a', 'b', 'a', 'b', 'c', 'd', 'a', 'b', 'c', 'd']

# %%
a=listSearch(T2,'a')

# %%
a
# Out:
# [0, 2, 4, 6, 10]

# %%
[a] + ['b']
# Out:
# [3, 'b']

# %%
def factorial (n) :
    if n==0 : return 1
    return n*factorial(n-1)

# %%
factorial(5)
# Out:
# 120

# %%
['a'] + ['b']
# Out:
# ['a', 'b']
